# %%
import matplotlib.pyplot as plt
plt.rc('font',family='Arial',size = 12)
fig, ax = plt.subplots(1, 3, figsize = (8, 3))
plt.subplots_adjust(hspace=0.05, wspace=0.3)

density = gaussian_kde(velocity)
xs = np.linspace(0,20,200)
ax[0].hist(velocity, density=True, bins='auto', color='#228B22',
                    alpha=0.7, rwidth=0.85)
ax[0].plot(xs, density(xs), color = 'red', linestyle = '-', linewidth = 1.5)
ax[0].set_xlim(0.2,xs[-1])
ax[0].set_xlabel('Velocity (m/s)')
ax[0].set_ylabel('Probability')

density = gaussian_kde(relative_velocity)
xs = np.linspace(-6,6,200)
ax[1].hist(relative_velocity, density=True, bins='auto', color='#228B22',
                    alpha=0.7, rwidth=0.85)
ax[1].plot(xs, density(xs), color = 'red', linestyle = '-', linewidth = 1.5)
ax[1].set_xlim(xs[0],xs[-1])
ax[1].set_xlabel('Relative_velocity (m/s)')
# ax[1].set_ylabel('Probability')

density = gaussian_kde(gap)
xs = np.linspace(0,70,200)
ax[2].hist(gap, density=True, bins='auto', color='#228B22',
                    alpha=0.7, rwidth=0.85)
ax[2].plot(xs, density(xs), color = 'red', linestyle = '-', linewidth = 1.5)
ax[2].set_xlim(xs[0],xs[-1])
ax[2].set_xlabel('Distance (m)')
# ax[2].set_ylabel('Probability')
plt.savefig('G:\\Test\\Car_following\\var_dist2.pdf',bbox_inches='tight')
